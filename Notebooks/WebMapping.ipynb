# %% [markdown]
# **CURSO**: Análisis Geoespacial, Departamento de Geociencias y Medio Ambiente, Universidad Nacional de Colombia - sede Medellín <br/>
# **Profesor**: Edier Aristizábal (evaristizabalg@unal.edu.co) <br />
# **Classroom code**: [32cjlau] <br />
# **Credits**: The content of this notebook is taken from several sources, mainly fromcreated an alternative world map and reflected what will happen to the situation in the country if certain parameters change. Since we do data visualization, and not geopolitics, we refrained from evaluating this data in any way. We employed a t-SNE machine learning algorithm to process data, and you are left to play with the unemployment rate, health care costs and other characteristics.. Every effort has been made to trace copyright holders of the materials used in this book. The author apologies for any unintentional omissions and would be pleased to add an acknowledgment in future editions.

# %% [markdown]
# ## Herramientas Web Mapping

# %% [markdown]
# ## Landsat on AWS
# Landsat 8 data is available for anyone to use via [Amazon S3](https://docs.opendata.aws/landsat-pds/readme.html). All Landsat 8 scenes are available from the start of imagery capture. All new Landsat 8 scenes are made available each day, often within hours of production.

# %% [markdown]
# ## [EOX COG-Explorer](https://eox.at/2018/05/explore-landsat-8-scenes-with-cog-explorer/)
# This app allows you to visually inspect individual Cloud Optimized GeoTIFFs (COGs) like scenes from the Landsat-8 archive on [Amazon S3](https://geotiffjs.github.io/cog-explorer/#long=16.370&lat=48.210&zoom=5&scene=&bands=&pipeline=)

# %% [markdown]
# ## [Land viewer](https://eos.com/products/landviewer/)
# Land Viewer is a satellite observation imagery tool that allows for on-the-fly searching, processing and getting valuable insights from satellite data to tackle real business issues

# %% [markdown]
# ## Spectator
# [Spectator Earth](https://app.spectator.earth/) offers a Web app providing Earth Observation imagery, mainly from open data satellites like the Sentinel and the Landsat family

# %% [markdown]
# ## t-SNE
# It has been created an alternative world map and reflected what will happen to the situation in the country if certain parameters change. Since we do data visualization, and not geopolitics, we refrained from evaluating this data in any way. They employed a [t-SNE](https://projects.interacta.io/country-tsne/) machine learning algorithm to process data, and you are left to play with the unemployment rate, health care costs and other characteristics.

# %% [markdown]
# ## Carto
# [Carto](https://carto.com/) is a Software as a Service (SaaS) cloud computing platform that provides GIS, web mapping, and spatial data science tools.

# %% [markdown]
# ## Kepler
# [Kepler](https://kepler.gl/) is a high-performance web-based tool created by the Uber's Visualization Team for visual exploration of large scale geospatial datasets. It is built on top of deck.gl – another framework for visual exploratory data analysis of large datasets by Uber.
#
# kepler.gl can also be used inside our [Jupyter notebook](https://www.analyticsvidhya.com/blog/2020/06/learn-visualize-geospatial-data-jupyter-kepler/#:~:text=Kepler.gl%20is%20a%20high,of%20large%20datasets%20by%20Uber.), which makes it a handy tool for everyone in the data science community.
#
# <center><img src="http://1fykyq3mdn5r21tpna3wkdyi-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/image13.gif" width="1000"></center>

# %% [markdown]
# ## SOAR
# [SOAR](https://soar.earth/) is a digital atlas of all the world's maps and imagery. Examples of content include —
# satellite imagery, aerial imagery, remote sensing data, drone images, orthomosaics, community content, and more.
#
# <center><img src="https://www.cursosteledeteccion.com/wp-content/uploads/2021/12/2-768x356.png" width="1000"></center>
# ‍

# %% [markdown]
# ### [ESRI](https://www.esri.com/en-us/arcgis/products/unlock-earths-secrets#apps)
#
# The [ArcGIS Imagery Book](https://learn.arcgis.com/en/arcgis-imagery-book/)
#
# [ESRI](https://www.arcgis.com/apps/MinimalGallery/index.html?appid=cff0dd2940984c209d29d6ed3c41b99a) Imagery apps
#
# [ArcGIS Living Atlas of tha World](https://livingatlas.arcgis.com/en/browse/#d=1&cont=true&categories=Imagery%3A1111)
#
# [Satellite map](https://geoxc-apps2.bd.esri.com/Visualization/sat2/index.html)
#
# [Imagery with metadata](https://www.arcgis.com/apps/mapviewer/index.html?webmap=c03a526d94704bfb839445e80de95495)

# %% [markdown]
# [Streamlit](https://streamlit.geemap.org/) for geospatial applications. This multi-page web app developed by [Quisheng Wu](https://blog.streamlit.io/tag/tutorials/) demonstrates various interactive web apps created using streamlit and open-source mapping libraries, such as leafmap, geemap, pydeck, and kepler.gl.

# %% [markdown]
# ## [Sentinelhub Playground](https://apps.sentinel-hub.com/sentinel-playground/?source=L8)
# The Sentinel Hub Playground provides a web GIS to explore satellite imagery from platorms Sentinel-2, Landsat-8 and MODIS. Sentinel and Landsat data can be displayed in a variety of predefined band combinations and spectral indices as they are generated on the fly. Costom band combination can be created by the user.

# %% [markdown]
# ## [Geocoder](https://geocode.localfocus.nl/)
# Geocoding is the process of transforming a description of a location—such as a pair of coordinates, an address, or a name of a place—to a location on the earth's surface. You can geocode by entering one location description at a time or by providing many of them at once in a table. The resulting locations are output as geographic features with attributes, which can be used for mapping or spatial analysis.

# %% [markdown]
# ## RAWGraphs
# [RAWGraphs](https://app.rawgraphs.io/) is an open source data visualization framework built with the goal of making the visual representation of complex data easy for everyone.

# %% [markdown]
# ## Palladio
# [Palladio](http://hdlab.stanford.edu/palladio/) is a widely-used web-based tool for visualizing data using networks and maps

# %% [markdown]
# ## Eastraea - EarthAI
# [EarthAI](https://astraea.earth/platform/) is an integrated imagery analysis platform designed to enable users to discover, access, and process Earth observation data

# %% [markdown]
# ### Leafmap
# [leafmap](https://leafmap.org/) is an open-source Python package for interactive mapping and geospatial analysis with minimal coding in a Jupyter environment. It is built upon several other open-source packages, such as folium and ipyleaflet (for creating interactive
#  maps), WhiteboxTools and whiteboxgui (for analyzing geospatial data), and ipywidgets (for designing interactive graphical user interface [GUI]).
#
# Leafmap is a very powerful tool for geospatial data science, with many convenient functions for loading, analyzing and visualizing geospatial datasets, which makes it particularly suited for novice users with limited programming skills.
#
# There are so many great features offered by leafmap, one of them is the drawing tool. We are going to show that the drawing tool not only can be
# used to draw shapes on the map and save the drawn features into a file (e.g., GeoJSON, Shapefile, and GeoPackage ), but also can be used as a query tool.
#
# The leafmap package has some optional dependencies which can be challenging to install on some computers. Follow [these instructions](https://leafmap.org/installation/) during the installation.

# %%
# !pip install leafmap
# Important library for many geopython libraries
# !apt install gdal-bin python-gdal python3-gdal 
# Install rtree - Geopandas requirment
# !apt install python3-rtree 
# Install Geopandas
# !pip install git+git://github.com/geopandas/geopandas.git
# Install descartes - Geopandas requirment
# !pip install descartes

# %%
# !conda install geopandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0
# Examining numpy:  96%|█████████▌| 178/185 [00:32<00:01,  5.51it/s]
# Examining icu:  97%|█████████▋| 179/185 [00:33<00:01,  5.51it/s]
# Examining icu:  97%|█████████▋| 180/185 [00:33<00:01,  3.83it/s]
# Examining hdf4:  97%|█████████▋| 180/185 [00:33<00:01,  3.83it/s]
# Examining winpty:  98%|█████████▊| 181/185 [00:33<00:01,  3.83it/s]
# Examining font-ttf-source-code-pro:  98%|█████████▊| 182/185 [00:33<00:00,  3.83it/s]
# Examining zlib:  99%|█████████▉| 183/185 [00:33<00:00,  3.83it/s]
# Examining krb5:  99%|█████████▉| 184/185 [00:33<00:00,  3.83it/s]
#
#
# Determining conflicts:   0%|          | 0/185 [00:00<?, ?it/s]
# Examining conflict for vc xerces-c pytz snuggs anyio cligj freexl nbformat parso pygments jupyter_server sqlite importlib_metadata postgresql libxml2 libgdal pyqt5-sip pysocks lerc kealib lcms2 idna mistune notebook geos xz numpy-base gettext pip libssh2 cfitsio pyopenssl bleach jupyterlab_pygments libglib pixman jpeg brotli geotiff wincertstore six jbig urllib3 python libtiff qt libpng zipp openssl hdf5 jinja2 packaging certifi fonttools wheel wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib fontconfig ipython proj send2trash zstd libzlib lz4-c munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert importlib-metadata cryptography libclang tk decorator curl pywin32 matplotlib-inline charset-normalizer brotlipy libcurl expat libnetcdf libwebp setuptools traitlets cycler jedi poppler ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions cairo jupyter_core websocket-client pyzmq pandas babel pyqt libwebp-base matplotlib-base terminado libffi python-dateutil libdeflate pillow win_inet_pton pyqtwebengine nest-asyncio openjpeg pyparsing debugpy mkl_fft libiconv libkml argon2-cffi-bindings sip nbclient click libpq jupyterlab_server tiledb bzip2 kiwisolver nbclassic click-plugins cffi ipykernel libspatialite backcall attrs bottleneck sniffio mkl_random prometheus_client pcre geopandas affine boost-cpp freetype librttopo numpy icu hdf4 winpty zlib krb5:   0%|          | 0/185 [00:00<?, ?it/s]
# Examining conflict for vc xerces-c pytz snuggs anyio cligj freexl nbformat parso pygments jupyter_server sqlite importlib_metadata postgresql libxml2 libgdal pyqt5-sip pysocks lerc kealib lcms2 idna mistune notebook geos xz numpy-base gettext pip libssh2 cfitsio pyopenssl bleach jupyterlab_pygments libglib pixman jpeg brotli geotiff wincertstore six jbig urllib3 python libtiff qt libpng zipp openssl hdf5 jinja2 packaging certifi fonttools wheel wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib fontconfig ipython proj send2trash zstd libzlib lz4-c munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert importlib-metadata cryptography libclang tk decorator vs2015_runtime curl pywin32 matplotlib-inline charset-normalizer brotlipy libcurl expat libnetcdf libwebp setuptools traitlets cycler jedi poppler ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions cairo jupyter_core websocket-client pyzmq pandas babel pyqt libwebp-base matplotlib-base terminado libffi python-dateutil libdeflate pillow win_inet_pton pyqtwebengine nest-asyncio openjpeg pyparsing debugpy mkl_fft libiconv libkml argon2-cffi-bindings sip nbclient click libpq jupyterlab_server tiledb bzip2 kiwisolver nbclassic click-plugins cffi ipykernel libspatialite backcall attrs bottleneck sniffio mkl_random prometheus_client pcre geopandas affine boost-cpp freetype librttopo numpy icu hdf4 winpty zlib krb5:   1%|          | 1/185 [00:04<13:35,  4.43s/it]
# Examining conflict for vc xerces-c pytz snuggs anyio cligj freexl nbformat parso pygments jupyter_server sqlite importlib_metadata postgresql libxml2 libgdal pyqt5-sip pysocks lerc kealib lcms2 idna mistune notebook geos xz numpy-base gettext pip libssh2 cfitsio pyopenssl bleach jupyterlab_pygments libglib pixman jpeg brotli geotiff wincertstore six jbig urllib3 python libtiff qt libpng zipp openssl hdf5 jinja2 packaging certifi fonttools wheel wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib fontconfig ipython proj send2trash zstd libzlib lz4-c munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert importlib-metadata cryptography libclang tk decorator vs2015_runtime curl pywin32 matplotlib-inline charset-normalizer brotlipy libcurl expat libnetcdf libwebp setuptools traitlets cycler jedi poppler ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions cairo jupyter_core websocket-client pyzmq pandas babel pyqt libwebp-base matplotlib-base terminado libffi python-dateutil libdeflate pillow win_inet_pton pyqtwebengine nest-asyncio openjpeg pyparsing debugpy mkl_fft libiconv libkml argon2-cffi-bindings sip nbclient click libpq jupyterlab_server tiledb bzip2 kiwisolver nbclassic click-plugins cffi ipykernel libspatialite backcall attrs bottleneck sniffio mkl_random prometheus_client pcre geopandas affine boost-cpp freetype librttopo numpy icu hdf4 winpty zlib krb5:   1%|          | 2/185 [00:04<06:45,  2.22s/it]
# Examining conflict for vc xerces-c pytz snuggs cligj freexl nbformat parso pygments sqlite importlib_metadata postgresql libxml2 libgdal pysocks kealib idna mistune notebook geos xz numpy-base pip libssh2 pyopenssl bleach jupyterlab_pygments pixman jpeg geotiff wincertstore six urllib3 libtiff qt libpng zipp openssl hdf5 jinja2 packaging certifi fonttools wheel wcwidth webencodings colorama requests jsonschema pandocfilters defusedxml entrypoints jupyter_client matplotlib ipython send2trash zstd lz4-c munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions nbconvert cryptography tk decorator pywin32 curl libcurl expat libnetcdf libwebp setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service numexpr pywinpty testpath tornado typing_extensions cairo jupyter_core websocket-client pyzmq pandas babel pyqt terminado python-dateutil pillow win_inet_pton openjpeg pyparsing mkl_fft libiconv libkml sip click libpq bzip2 kiwisolver click-plugins cffi ipykernel libspatialite backcall attrs bottleneck prometheus_client pcre geopandas affine boost-cpp freetype numpy icu hdf4 zlib krb5:   1%|          | 2/185 [00:08<06:45,  2.22s/it]
# Examining conflict for vc xerces-c pytz snuggs cligj freexl nbformat parso pygments sqlite importlib_metadata postgresql libxml2 libgdal pysocks kealib idna mistune notebook geos xz numpy-base pip libssh2 pyopenssl bleach jupyterlab_pygments pixman jpeg geotiff wincertstore six urllib3 libtiff qt libpng zipp openssl hdf5 jinja2 packaging certifi fonttools wheel wcwidth webencodings colorama requests jsonschema pandocfilters defusedxml entrypoints jupyter_client matplotlib ipython send2trash zstd lz4-c munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions nbconvert cryptography tk decorator pywin32 curl libcurl expat libnetcdf libwebp setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service numexpr pywinpty testpath tornado typing_extensions cairo jupyter_core websocket-client pyzmq pandas babel pyqt terminado python-dateutil pillow win_inet_pton openjpeg pyparsing mkl_fft libiconv libkml sip click libpq bzip2 kiwisolver click-plugins cffi ipykernel libspatialite backcall attrs bottleneck prometheus_client pcre geopandas affine boost-cpp freetype numpy icu hdf4 zlib krb5:   2%|▏         | 3/185 [00:08<09:31,  3.14s/it]
# Examining conflict for libgdal xerces-c rasterio:   2%|▏         | 3/185 [00:12<09:31,  3.14s/it]
# Examining conflict for libgdal xerces-c rasterio:   2%|▏         | 4/185 [00:12<09:57,  3.30s/it]
# Examining conflict for pandas babel pytz jupyterlab_server geopandas matplotlib:   2%|▏         | 4/185 [00:12<09:57,  3.30s/it]
# Examining conflict for pandas babel pytz jupyterlab_server geopandas matplotlib:   3%|▎         | 5/185 [00:12<07:01,  2.34s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server importlib_metadata pyqt5-sip pysocks idna mistune notebook numpy-base pip pyopenssl bleach jupyterlab_pygments wincertstore six urllib3 python zipp jinja2 packaging wheel certifi fonttools wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib ipython send2trash munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions nbconvert importlib-metadata cryptography decorator pywin32 matplotlib-inline charset-normalizer brotlipy setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton pyqtwebengine nest-asyncio pyparsing debugpy mkl_fft argon2-cffi-bindings sip nbclient click jupyterlab_server kiwisolver nbclassic click-plugins cffi ipykernel backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine numpy:   3%|▎         | 5/185 [00:13<07:01,  2.34s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server importlib_metadata pyqt5-sip pysocks idna mistune notebook numpy-base pip pyopenssl bleach jupyterlab_pygments wincertstore six urllib3 python zipp jinja2 packaging wheel certifi fonttools wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib ipython send2trash munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions nbconvert importlib-metadata cryptography decorator pywin32 matplotlib-inline charset-normalizer brotlipy setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton pyqtwebengine nest-asyncio pyparsing debugpy mkl_fft argon2-cffi-bindings sip nbclient click jupyterlab_server kiwisolver nbclassic click-plugins cffi ipykernel backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine numpy:   3%|▎         | 6/185 [00:13<05:21,  1.80s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server sqlite importlib_metadata libgdal pyqt5-sip pysocks idna mistune notebook numpy-base pip pyopenssl bleach jupyterlab_pygments geotiff wincertstore six urllib3 python qt zipp jinja2 packaging wheel certifi fonttools wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib ipython proj send2trash munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions nbconvert importlib-metadata cryptography decorator pywin32 matplotlib-inline charset-normalizer brotlipy setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton pyqtwebengine nest-asyncio pyparsing debugpy mkl_fft argon2-cffi-bindings sip nbclient click jupyterlab_server kiwisolver nbclassic click-plugins cffi ipykernel libspatialite backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine numpy:   3%|▎         | 6/185 [00:17<05:21,  1.80s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server sqlite importlib_metadata libgdal pyqt5-sip pysocks idna mistune notebook numpy-base pip pyopenssl bleach jupyterlab_pygments geotiff wincertstore six urllib3 python qt zipp jinja2 packaging wheel certifi fonttools wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib ipython proj send2trash munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions nbconvert importlib-metadata cryptography decorator pywin32 matplotlib-inline charset-normalizer brotlipy setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton pyqtwebengine nest-asyncio pyparsing debugpy mkl_fft argon2-cffi-bindings sip nbclient click jupyterlab_server kiwisolver nbclassic click-plugins cffi ipykernel libspatialite backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine numpy:   4%|▍         | 7/185 [00:17<07:16,  2.45s/it]
# Examining conflict for pytz snuggs cligj nbformat parso pygments importlib_metadata postgresql libgdal pysocks idna mistune notebook numpy-base pip libssh2 pyopenssl bleach jupyterlab_pygments wincertstore six urllib3 python qt ca-certificates zipp openssl hdf5 jinja2 packaging certifi fonttools wheel wcwidth webencodings colorama requests jsonschema pandocfilters defusedxml entrypoints jupyter_client matplotlib ipython send2trash munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert cryptography decorator pywin32 setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service numexpr pywinpty testpath tornado typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt terminado python-dateutil pillow win_inet_pton pyparsing mkl_fft sip click libpq tiledb kiwisolver click-plugins cffi ipykernel backcall attrs bottleneck prometheus_client geopandas affine numpy krb5:   4%|▍         | 7/185 [00:22<07:16,  2.45s/it]
# Examining conflict for pytz snuggs cligj nbformat parso pygments importlib_metadata postgresql libgdal pysocks idna mistune notebook numpy-base pip libssh2 pyopenssl bleach jupyterlab_pygments wincertstore six urllib3 python qt ca-certificates zipp openssl hdf5 jinja2 packaging certifi fonttools wheel wcwidth webencodings colorama requests jsonschema pandocfilters defusedxml entrypoints jupyter_client matplotlib ipython send2trash munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert cryptography decorator pywin32 setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service numexpr pywinpty testpath tornado typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt terminado python-dateutil pillow win_inet_pton pyparsing mkl_fft sip click libpq tiledb kiwisolver click-plugins cffi ipykernel backcall attrs bottleneck prometheus_client geopandas affine numpy krb5:   4%|▍         | 8/185 [00:22<09:11,  3.11s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server libgdal pysocks lcms2 idna mistune notebook xz numpy-base pip pyopenssl bleach jupyterlab_pygments geotiff wincertstore six urllib3 libtiff zipp jinja2 packaging wheel certifi fonttools wcwidth webencodings colorama requests jsonschema pandocfilters defusedxml entrypoints jupyter_client matplotlib ipython proj send2trash zstd munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions nbconvert importlib-metadata cryptography decorator pywin32 matplotlib-inline charset-normalizer brotlipy setuptools traitlets cycler jedi poppler ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton nest-asyncio openjpeg pyparsing debugpy mkl_fft libkml argon2-cffi-bindings sip nbclient click jupyterlab_server tiledb kiwisolver nbclassic click-plugins cffi ipykernel backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine boost-cpp numpy:   4%|▍         | 8/185 [00:25<09:11,  3.11s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server libgdal pysocks lcms2 idna mistune notebook xz numpy-base pip pyopenssl bleach jupyterlab_pygments geotiff wincertstore six urllib3 libtiff zipp jinja2 packaging wheel certifi fonttools wcwidth webencodings colorama requests jsonschema pandocfilters defusedxml entrypoints jupyter_client matplotlib ipython proj send2trash zstd munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions nbconvert importlib-metadata cryptography decorator pywin32 matplotlib-inline charset-normalizer brotlipy setuptools traitlets cycler jedi poppler ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton nest-asyncio openjpeg pyparsing debugpy mkl_fft libkml argon2-cffi-bindings sip nbclient click jupyterlab_server tiledb kiwisolver nbclassic click-plugins cffi ipykernel backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine boost-cpp numpy:   5%|▍         | 9/185 [00:25<09:33,  3.26s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server importlib_metadata postgresql libgdal pyqt5-sip pysocks kealib idna mistune notebook numpy-base pip libssh2 pyopenssl bleach jupyterlab_pygments wincertstore six urllib3 python qt zipp openssl hdf5 jinja2 packaging certifi fonttools wheel wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib ipython send2trash munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert importlib-metadata cryptography decorator pywin32 curl matplotlib-inline charset-normalizer brotlipy libcurl libnetcdf setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton pyqtwebengine nest-asyncio pyparsing debugpy mkl_fft argon2-cffi-bindings sip nbclient click libpq jupyterlab_server tiledb kiwisolver nbclassic click-plugins cffi ipykernel backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine numpy krb5:   5%|▍         | 9/185 [00:29<09:33,  3.26s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server importlib_metadata postgresql libgdal pyqt5-sip pysocks kealib idna mistune notebook numpy-base pip libssh2 pyopenssl bleach jupyterlab_pygments wincertstore six urllib3 python qt zipp openssl hdf5 jinja2 packaging certifi fonttools wheel wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib ipython send2trash munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert importlib-metadata cryptography decorator pywin32 curl matplotlib-inline charset-normalizer brotlipy libcurl libnetcdf setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton pyqtwebengine nest-asyncio pyparsing debugpy mkl_fft argon2-cffi-bindings sip nbclient click libpq jupyterlab_server tiledb kiwisolver nbclassic click-plugins cffi ipykernel backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine numpy krb5:   5%|▌         | 10/185 [00:29<10:17,  3.53s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server sqlite postgresql libxml2 libgdal pysocks kealib lcms2 idna mistune notebook numpy-base pip libssh2 cfitsio pyopenssl bleach jupyterlab_pygments geotiff wincertstore six urllib3 python libtiff qt libpng zipp jinja2 hdf5 packaging wheel certifi fonttools wcwidth webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib fontconfig ipython proj send2trash zstd munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert importlib-metadata cryptography libclang decorator pywin32 curl matplotlib-inline charset-normalizer brotlipy libcurl libnetcdf setuptools traitlets cycler jedi poppler ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions cairo jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton pyqtwebengine nest-asyncio openjpeg pyparsing debugpy mkl_fft libkml argon2-cffi-bindings sip nbclient click libpq jupyterlab_server tiledb kiwisolver nbclassic click-plugins cffi ipykernel libspatialite backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine boost-cpp freetype numpy hdf4 zlib:   5%|▌         | 10/185 [00:34<10:17,  3.53s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server sqlite postgresql libxml2 libgdal pysocks kealib lcms2 idna mistune notebook numpy-base pip libssh2 cfitsio pyopenssl bleach jupyterlab_pygments geotiff wincertstore six urllib3 python libtiff qt libpng zipp jinja2 hdf5 packaging wheel certifi fonttools wcwidth webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib fontconfig ipython proj send2trash zstd munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert importlib-metadata cryptography libclang decorator pywin32 curl matplotlib-inline charset-normalizer brotlipy libcurl libnetcdf setuptools traitlets cycler jedi poppler ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions cairo jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton pyqtwebengine nest-asyncio openjpeg pyparsing debugpy mkl_fft libkml argon2-cffi-bindings sip nbclient click libpq jupyterlab_server tiledb kiwisolver nbclassic click-plugins cffi ipykernel libspatialite backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine boost-cpp freetype numpy hdf4 zlib:   6%|▌         | 11/185 [00:34<11:08,  3.84s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server libgdal pysocks idna mistune notebook numpy-base pip pyopenssl bleach jupyterlab_pygments wincertstore six urllib3 zipp jinja2 packaging wheel certifi fonttools wcwidth webencodings colorama requests jsonschema pandocfilters defusedxml entrypoints jupyter_client matplotlib ipython send2trash munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert importlib-metadata cryptography decorator pywin32 matplotlib-inline charset-normalizer brotlipy libnetcdf setuptools traitlets cycler jedi poppler ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton nest-asyncio pyparsing debugpy mkl_fft libkml argon2-cffi-bindings sip nbclient click jupyterlab_server tiledb bzip2 kiwisolver nbclassic click-plugins cffi ipykernel backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine boost-cpp numpy:   6%|▌         | 11/185 [00:37<11:08,  3.84s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server libgdal pysocks idna mistune notebook numpy-base pip pyopenssl bleach jupyterlab_pygments wincertstore six urllib3 zipp jinja2 packaging wheel certifi fonttools wcwidth webencodings colorama requests jsonschema pandocfilters defusedxml entrypoints jupyter_client matplotlib ipython send2trash munkres rasterio prompt-toolkit pickleshare pycparser jupyterlab typing-extensions libzip nbconvert importlib-metadata cryptography decorator pywin32 matplotlib-inline charset-normalizer brotlipy libnetcdf setuptools traitlets cycler jedi poppler ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton nest-asyncio pyparsing debugpy mkl_fft libkml argon2-cffi-bindings sip nbclient click jupyterlab_server tiledb bzip2 kiwisolver nbclassic click-plugins cffi ipykernel backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine boost-cpp numpy:   6%|▋         | 12/185 [00:37<10:53,  3.78s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server pyqt5-sip pysocks idna mistune notebook numpy-base pip pyopenssl bleach jupyterlab_pygments wincertstore six urllib3 python zipp jinja2 packaging wheel certifi fonttools wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib ipython send2trash munkres rasterio prompt-toolkit tzdata pickleshare pycparser jupyterlab typing-extensions nbconvert importlib-metadata cryptography decorator pywin32 matplotlib-inline charset-normalizer brotlipy setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton pyqtwebengine nest-asyncio pyparsing debugpy mkl_fft argon2-cffi-bindings sip nbclient click jupyterlab_server kiwisolver nbclassic click-plugins cffi ipykernel backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine numpy:   6%|▋         | 12/185 [00:42<10:53,  3.78s/it]
# Examining conflict for pytz snuggs anyio cligj nbformat parso pygments jupyter_server pyqt5-sip pysocks idna mistune notebook numpy-base pip pyopenssl bleach jupyterlab_pygments wincertstore six urllib3 python zipp jinja2 packaging wheel certifi fonttools wcwidth python_abi webencodings colorama requests jsonschema pandocfilters defusedxml pyqtchart entrypoints jupyter_client matplotlib ipython send2trash munkres rasterio prompt-toolkit tzdata pickleshare pycparser jupyterlab typing-extensions nbconvert importlib-metadata cryptography decorator pywin32 matplotlib-inline charset-normalizer brotlipy setuptools traitlets cycler jedi ipython_genutils pyrsistent markupsafe json5 mkl-service argon2-cffi numexpr pywinpty testpath tornado pyqt-impl typing_extensions jupyter_core websocket-client pyzmq pandas babel pyqt matplotlib-base terminado python-dateutil pillow win_inet_pton pyqtwebengine nest-asyncio pyparsing debugpy mkl_fft argon2-cffi-bindings sip nbclient click jupyterlab_server kiwisolver nbclassic click-plugins cffi ipykernel backcall attrs bottleneck sniffio mkl_random prometheus_client geopandas affine numpy:   7%|▋         | 13/185 [00:42<11:04,  3.86s/it]
# ...
# prometheus_client -> twisted -> idna[version='>=0.6,!=2.3|>=2.4']
# jupyterlab_server -> requests -> idna[version='>=2.5,<2.7|>=2.5,<2.8|>=2.5,<2.9|>=2.5,<3|>=2.5,<4']
#
# Package libkml conflicts for:
# rasterio -> libgdal[version='>=3.0.2,<3.1.0a0'] -> libkml[version='>=1.3.0,<1.4.0a0']
# libkml
# libgdal -> libkml[version='>=1.3.0,<1.4.0a0']
#
# Package json5 conflicts for:
# jupyterlab_server -> json5
# json5
# jupyterlab -> jupyterlab_server[version='>=2.10,<3'] -> json5
#
# Package importlib_metadata conflicts for:
# ipykernel -> argcomplete[version='>=1.12.3'] -> importlib_metadata[version='>=0.23,<5']
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> importlib_metadata
# importlib_metadata
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> importlib_metadata
# geopandas -> sqlalchemy -> importlib_metadata
# jsonschema -> importlib_metadata
#
# Package backports.shutil_get_terminal_size conflicts for:
# ipykernel -> ipython[version='>=5.0'] -> backports.shutil_get_terminal_size
# ipython -> backports.shutil_get_terminal_size
# jupyterlab -> ipython -> backports.shutil_get_terminal_size
#
# Package websocket-client conflicts for:
# websocket-client
# jupyter_server -> websocket-client
# nbclassic -> jupyter_server[version='>=1.8.0,<2.0.0'] -> websocket-client
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> websocket-client
# jupyterlab_server -> jupyter_server[version='>=1.4,<2'] -> websocket-client
#
# Package libspatialite conflicts for:
# libspatialite
# rasterio -> libgdal[version='>=3.0.2,<3.1.0a0'] -> libspatialite[version='>=4.3.0a,<4.4.0a0|>=5.0.1,<5.1.0a0']
# libgdal -> libspatialite[version='>=4.3.0a,<4.4.0a0|>=5.0.1,<5.1.0a0']
#
# Package python_abi conflicts for:
# python_abi
# click-plugins -> click[version='>=3.0'] -> python_abi=3.9[build=*_cp39]
# rasterio -> python_abi=3.9[build=*_cp39]
# matplotlib-base -> certifi[version='>=2020.06.20'] -> python_abi=3.9[build=*_cp39]
# setuptools -> certifi[version='>=2016.9.26'] -> python_abi=3.9[build=*_cp39]
# pyqt5-sip -> python_abi=3.9[build=*_cp39]
# pyqtwebengine -> python_abi=3.9[build=*_cp39]
# certifi -> python_abi=3.9[build=*_cp39]
# tornado -> certifi -> python_abi=3.9[build=*_cp39]
# urllib3 -> certifi -> python_abi=3.9[build=*_cp39]
# cligj -> click[version='>=4.0'] -> python_abi=3.9[build=*_cp39]
# snuggs -> click -> python_abi=3.9[build=*_cp39]
# pyqtchart -> python_abi=3.9[build=*_cp39]
# matplotlib -> pyqt -> python_abi=3.9[build=*_cp39]
# requests -> certifi[version='>=2017.4.17'] -> python_abi=3.9[build=*_cp39]
# click -> python_abi=3.9[build=*_cp39]
# pyqt-impl -> python_abi=3.9[build=*_cp39]
# pyqt -> python_abi=3.9[build=*_cp39]
#
# Package pyqt-impl conflicts for:
# pyqt -> pyqt-impl==5.12.3=py39h415ef7b_8
# matplotlib -> pyqt -> pyqt-impl==5.12.3=py39h415ef7b_8
# pyqt-impl
# pyqtwebengine -> pyqt-impl==5.12.3=py39h415ef7b_8
# pyqtchart -> pyqt-impl==5.12.3=py39h415ef7b_8
#
# Package libgdal conflicts for:
# geopandas -> fiona -> libgdal[version='>=2.2.2,<2.3.0a0|>=2.3.3,<2.4.0a0|>=3.0.2,<3.1.0a0']
# libgdal
# rasterio -> libgdal[version='>=2.2.2,<2.3.0a0|>=2.3.3,<2.4.0a0|>=3.0.2,<3.1.0a0|>=3.3.3,<3.4.0a0']
#
# Package ipython conflicts for:
# notebook -> ipykernel -> ipython[version='>=4.0.0|>=4.0|>=5.0|>=7.23.1|>=7.23.1,<8.0']
# ipykernel -> ipython[version='>=4.0.0|>=4.0|>=5.0|>=7.23.1|>=7.23.1,<8.0']
# ipython
# jupyterlab -> ipython
#
# Package pyqt conflicts for:
# matplotlib -> pyqt[version='5.*|5.6.*|5.9.*|>=5.6,<6.0a0|>=5.9.2,<5.10.0a0']
# geopandas -> matplotlib -> pyqt[version='5.*|5.6.*|5.9.*|>=5.6,<6.0a0|>=5.9.2,<5.10.0a0']
# pyqt
#
# Package curl conflicts for:
# rasterio -> libgdal[version='>=2.2.2,<2.3.0a0'] -> curl
# curl
# libgdal -> libnetcdf=4.8 -> curl[version='>=7.78.0,<8.0a0|>=7.80.0,<8.0a0']
# libgdal -> curl
# libnetcdf -> curl[version='>=7.78.0,<8.0a0']
# tiledb -> curl[version='>=7.80.0,<8.0a0']
#
# Package pandocfilters conflicts for:
# pandocfilters
# jupyter_server -> nbconvert -> pandocfilters[version='>=1.4.1']
# notebook -> nbconvert -> pandocfilters[version='>=1.4.1']
# nbconvert -> pandocfilters[version='>=1.4.1']
#
# Package hdf5 conflicts for:
# hdf5
# kealib -> hdf5[version='>=1.10.1,<1.10.2.0a0|>=1.10.2,<1.10.3.0a0|>=1.10.4,<1.10.5.0a0|>=1.10.6,<1.10.7.0a0|>=1.8.18,<1.8.19.0a0|>=1.12.1,<1.12.2.0a0']
# libgdal -> libnetcdf=4.8 -> hdf5[version='*|>=1.8.20,<1.9.0a0|>=1.8.18,<1.9.0a0',build=nompi_*]
# libnetcdf -> hdf5[version='*|>=1.10.1,<1.10.2.0a0|>=1.10.2,<1.10.3.0a0|>=1.10.4,<1.10.5.0a0|>=1.10.6,<1.10.7.0a0|>=1.8.20,<1.9.0a0|>=1.8.18,<1.9.0a0|>=1.8.18,<1.8.19.0a0|>=1.12.1,<1.12.2.0a0',build=nompi_*]
# rasterio -> libgdal[version='>=3.0.2,<3.1.0a0'] -> hdf5[version='>=1.10.1,<1.10.2.0a0|>=1.10.4,<1.10.5.0a0|>=1.10.6,<1.10.7.0a0|>=1.8.18,<1.8.19.0a0|>=1.12.1,<1.12.2.0a0']
# libgdal -> hdf5[version='>=1.10.1,<1.10.2.0a0|>=1.10.2,<1.10.3.0a0|>=1.10.4,<1.10.5.0a0|>=1.10.6,<1.10.7.0a0|>=1.8.18,<1.8.19.0a0|>=1.12.1,<1.12.2.0a0']
#
# Package libssh2 conflicts for:
# libnetcdf -> libssh2
# libssh2
# tiledb -> curl -> libssh2[version='1.*|>=1.8.0,<2.0a0|>=1.8.2,<2.0a0|>=1.9.0,<2.0a0|>=1.10.0,<2.0a0']
# cfitsio -> libcurl[version='>=7.79.1,<8.0a0'] -> libssh2[version='>=1.10.0,<2.0a0|>=1.9.0,<2.0a0']
# libnetcdf -> curl -> libssh2[version='1.*|>=1.8.0,<2.0a0|>=1.8.2,<2.0a0|>=1.9.0,<2.0a0|>=1.10.0,<2.0a0']
# poppler -> libcurl[version='>=7.79.1,<8.0a0'] -> libssh2[version='>=1.10.0,<2.0a0|>=1.9.0,<2.0a0']
# curl -> libssh2[version='1.*|>=1.8.0,<2.0a0|>=1.8.2,<2.0a0|>=1.9.0,<2.0a0|>=1.10.0,<2.0a0']
# proj -> libcurl[version='>=7.80.0,<8.0a0'] -> libssh2[version='>=1.10.0,<2.0a0|>=1.9.0,<2.0a0']
# hdf5 -> libcurl[version='>=7.81.0,<8.0a0'] -> libssh2[version='>=1.10.0,<2.0a0']
# libgdal -> libcurl[version='>=7.80.0,<8.0a0'] -> libssh2[version='1.*|>=1.10.0,<2.0a0|>=1.9.0,<2.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# libcurl -> libssh2[version='>=1.10.0,<2.0a0|>=1.8.0,<2.0a0|>=1.8.2,<2.0a0|>=1.9.0,<2.0a0']
#
# Package twisted conflicts for:
# prometheus_client -> twisted
# notebook -> prometheus_client -> twisted
# jupyter_server -> prometheus_client -> twisted
#
# Package m2w64-gmp conflicts for:
# pywinpty -> m2w64-gcc-libs -> m2w64-gmp
# libffi -> m2w64-gcc-libs -> m2w64-gmp
#
# Package fonts-conda-forge conflicts for:
# fonts-conda-forge
# fonts-conda-ecosystem -> fonts-conda-forge
# poppler -> fonts-conda-ecosystem -> fonts-conda-forge
#
# Package ipaddress conflicts for:
# notebook -> ipaddress
# jupyterlab_server -> notebook[version='>=4.2.0'] -> ipaddress
# cryptography -> ipaddress
# pyopenssl -> cryptography[version='>=2.8'] -> ipaddress
# requests -> urllib3[version='>=1.21.1,<1.27'] -> ipaddress
# urllib3 -> ipaddress
# jupyterlab -> notebook[version='>=4.3.1'] -> ipaddress
# nbclassic -> notebook[version='<7'] -> ipaddress
#
# Package importlib-metadata conflicts for:
# click -> importlib-metadata
# cligj -> click[version='>=4.0'] -> importlib-metadata
# importlib_metadata -> importlib-metadata[version='>=1.1.3,<1.1.4.0a0|>=1.6.0,<1.6.1.0a0|>=1.6.1,<1.6.2.0a0|>=1.7.0,<1.7.1.0a0|>=2.0.0,<2.0.1.0a0|>=3.10.0,<3.10.1.0a0|>=4.6.4,<4.6.5.0a0|>=4.8.1,<4.8.2.0a0|>=4.8.2,<4.8.3.0a0|>=3.7.3,<3.7.4.0a0']
# ipykernel -> importlib-metadata[version='<5']
# importlib-metadata
# jsonschema -> importlib_metadata -> importlib-metadata[version='>=1.1.3,<1.1.4.0a0|>=1.6.0,<1.6.1.0a0|>=1.6.1,<1.6.2.0a0|>=1.7.0,<1.7.1.0a0|>=2.0.0,<2.0.1.0a0|>=3.10.0,<3.10.1.0a0|>=4.6.4,<4.6.5.0a0|>=4.8.1,<4.8.2.0a0|>=4.8.2,<4.8.3.0a0|>=3.7.3,<3.7.4.0a0']
# geopandas -> sqlalchemy -> importlib-metadata
# notebook -> ipykernel -> importlib-metadata[version='<5']
# snuggs -> click -> importlib-metadata
# rasterio -> click[version='>=4'] -> importlib-metadata
# click-plugins -> click[version='>=3.0'] -> importlib-metadata
#
# Package async_generator conflicts for:
# anyio -> async_generator
# nbconvert -> nbclient[version='>=0.5.0,<0.6.0'] -> async_generator
# nbclient -> async_generator
# jupyter_server -> anyio[version='>=2.0.2'] -> async_generator
#
# Package mistune conflicts for:
# mistune
# nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# jupyter_server -> nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# notebook -> nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
#
# Package wcwidth conflicts for:
# ipython -> prompt-toolkit[version='>=2.0.0,<3.1.0,!=3.0.0,!=3.0.1'] -> wcwidth
# prompt-toolkit -> wcwidth
# wcwidth
#
# Package pandoc conflicts for:
# notebook -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# jupyter_server -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
#
# Package pyqtchart conflicts for:
# pyqtchart
# matplotlib -> pyqt -> pyqtchart==5.12=py39h415ef7b_8
# pyqt -> pyqtchart==5.12=py39h415ef7b_8
#
# Package proj4 conflicts for:
# rasterio -> libgdal[version='>=2.3.3,<2.4.0a0'] -> proj4[version='>=4.9.3,<4.9.4.0a0|>=5.2.0,<5.2.1.0a0']
# libspatialite -> proj4[version='>=4.9.3,<4.9.4.0a0|>=5.1.0,<5.1.1.0a0|>=5.2.0,<5.2.1.0a0']
# geotiff -> proj4[version='>=4.9.3,<4.9.4.0a0|>=5.2.0,<5.2.1.0a0']
# libgdal -> proj4[version='>=4.9.3,<4.9.4.0a0|>=5.1.0,<5.1.1.0a0|>=5.2.0,<5.2.1.0a0']
# geopandas -> pyproj -> proj4[version='>=5.1.0,<5.1.1.0a0|>=5.2.0,<5.2.1.0a0']
#
# Package notebook conflicts for:
# notebook
# jupyterlab -> notebook[version='>=4.3|>=4.3.1']
# jupyterlab_server -> notebook[version='>=4.2.0']
# nbclassic -> notebook[version='<7']
# jupyterlab -> nbclassic[version='>=0.2,<1'] -> notebook[version='<7|>=4.2.0']
#
# Package chardet conflicts for:
# requests -> chardet[version='>=3.0.2,<3.1.0|>=3.0.2,<4|>=3.0.2,<5']
# pip -> requests -> chardet[version='>=3.0.2,<3.1.0|>=3.0.2,<4|>=3.0.2,<5']
# jupyterlab_server -> requests -> chardet[version='>=3.0.2,<3.1.0|>=3.0.2,<4|>=3.0.2,<5']
#
# Package charset-normalizer conflicts for:
# jupyterlab_server -> requests -> charset-normalizer[version='>=2.0.0,<2.1.0']
# charset-normalizer
# pip -> requests -> charset-normalizer[version='>=2.0.0,<2.1.0']
# requests -> charset-normalizer[version='>=2.0.0,<2.1.0']
#
# Package contextlib2 conflicts for:
# jsonschema -> importlib_metadata -> contextlib2
# importlib_metadata -> contextlib2
#
# Package numpydoc conflicts for:
# jedi -> numpydoc
# ipython -> jedi[version='>=0.10,<0.18'] -> numpydoc
#
# Package tiledb conflicts for:
# rasterio -> libgdal[version='>=3.0.2,<3.1.0a0'] -> tiledb[version='>=1.6.3,<2.0a0|>=2.2,<3.0a0|>=2.5.2,<2.6.0a0']
# libgdal -> tiledb[version='>=1.6.3,<2.0a0|>=2.2,<3.0a0|>=2.5.2,<2.6.0a0']
# tiledb
#
# Package msys2-conda-epoch conflicts for:
# libffi -> m2w64-gcc-libs -> msys2-conda-epoch[version='>=20160418']
# pywinpty -> m2w64-gcc-libs -> msys2-conda-epoch[version='>=20160418']
# libgdal -> m2w64-xz -> msys2-conda-epoch[version='>=20160418']
#
# Package unicodedata2 conflicts for:
# fonttools -> unicodedata2[version='>=13.0.0']
# matplotlib-base -> fonttools[version='>=4.22.0'] -> unicodedata2[version='>=13.0.0']
#
# Package cairo conflicts for:
# cairo
# libgdal -> poppler[version='>=21.11.0,<21.12.0a0'] -> cairo[version='>=1.16.0,<1.17.0a0']
# poppler -> cairo[version='>=1.16.0,<1.17.0a0']
#
# Package typing conflicts for:
# importlib-metadata -> typing_extensions[version='>=3.6.4'] -> typing[version='>=3.7.4']
# anyio -> typing_extensions -> typing[version='>=3.7.4']
# typing_extensions -> typing[version='>=3.7.4']
#
# Package nbclassic conflicts for:
# nbclassic
# jupyterlab -> nbclassic[version='>=0.2,<1']
#
# Package attrs conflicts for:
# prometheus_client -> twisted -> attrs[version='>=17.4.0|>=19.2.0']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> attrs[version='>=17.4.0']
# attrs
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> attrs[version='>=17.4.0']
# geopandas -> fiona -> attrs[version='>=17']
# rasterio -> attrs[version='>=16.0.0']
# jsonschema -> attrs[version='>=17.4.0']
#
# Package boost-cpp conflicts for:
# libgdal -> libkml[version='>=1.3.0,<1.4.0a0'] -> boost-cpp[version='>=1.74.0,<1.74.1.0a0']
# libkml -> boost-cpp[version='>=1.74.0,<1.74.1.0a0']
# poppler -> boost-cpp[version='>=1.74.0,<1.74.1.0a0']
# boost-cpp
#
# Package asn1crypto conflicts for:
# urllib3 -> cryptography[version='>=1.3.4'] -> asn1crypto[version='>=0.21.0']
# pyopenssl -> cryptography[version='>=2.8'] -> asn1crypto[version='>=0.21.0']
# cryptography -> asn1crypto[version='>=0.21.0']
#
# Package cfitsio conflicts for:
# rasterio -> libgdal[version='>=3.0.2,<3.1.0a0'] -> cfitsio[version='>=3.470,<3.471.0a0|>=4.0.0,<4.0.1.0a0']
# cfitsio
# libgdal -> cfitsio[version='>=3.470,<3.471.0a0|>=4.0.0,<4.0.1.0a0']
#
# Package brotli conflicts for:
# brotli
# matplotlib-base -> fonttools[version='>=4.22.0'] -> brotli[version='>=1.0.1']
# fonttools -> brotli[version='>=1.0.1']
#
# Package typing-extensions conflicts for:
# typing-extensions
# argon2-cffi -> typing-extensions
# jupyter_server -> argon2-cffi -> typing-extensions
# notebook -> argon2-cffi -> typing-extensions
#
# Package libboost conflicts for:
# libgdal -> libkml[version='>=1.3.0,<1.4.0a0'] -> libboost[version='>=1.65.1,<1.66.0a0|>=1.67.0,<1.67.1.0a0|>=1.73.0,<1.73.1.0a0']
# boost-cpp -> libboost[version='1.65.1|1.65.1|1.65.1|1.67.0|1.67.0|1.71.0|1.71.0|1.73.0',build='vc9h83875ae_3|h95ae18b_4|hfd51bdf_4|h86230c1_4|ha9fde0e_0|h6c2663c_11|h33f27b4_11|hd43e919_0|vc14h7b94727_3']
# libkml -> libboost[version='>=1.65.1,<1.66.0a0|>=1.67.0,<1.67.1.0a0|>=1.73.0,<1.73.1.0a0']
#
# Package libxml2 conflicts for:
# rasterio -> libgdal[version='>=3.0.2,<3.1.0a0'] -> libxml2[version='>=2.9.12,<2.10.0a0|>=2.9.8,<2.10.0a0|>=2.9.9,<2.10.0a0']
# postgresql -> libxml2[version='>=2.9.12,<2.10.0a0']
# libspatialite -> libxml2[version='>=2.9.12,<2.10.0a0|>=2.9.8,<2.10.0a0|>=2.9.4,<2.10.0a0|>=2.9.9,<2.10.0a0']
# cairo -> fontconfig[version='>=2.13.1,<3.0a0'] -> libxml2[version='>=2.9.12,<2.10.0a0']
# libgdal -> libspatialite[version='>=4.3.0a,<4.4.0a0'] -> libxml2[version='>=2.9.4,<2.10.0a0']
# libxml2
# fontconfig -> libxml2[version='>=2.9.12,<2.10.0a0']
# poppler -> fontconfig[version='>=2.13.1,<3.0a0'] -> libxml2[version='>=2.9.12,<2.10.0a0']
# libgdal -> libxml2[version='>=2.9.12,<2.10.0a0|>=2.9.8,<2.10.0a0|>=2.9.9,<2.10.0a0']
#
# Package m2w64-gcc-libs-core conflicts for:
# pywinpty -> m2w64-gcc-libs-core
# libffi -> m2w64-gcc-libs -> m2w64-gcc-libs-core
# terminado -> pywinpty -> m2w64-gcc-libs-core
#
# Package postgresql conflicts for:
# rasterio -> libgdal[version='>=3.0.2,<3.1.0a0'] -> postgresql
# libgdal -> postgresql
# postgresql
#
# Package font-ttf-dejavu-sans-mono conflicts for:
# fonts-conda-forge -> font-ttf-dejavu-sans-mono
# fonts-conda-ecosystem -> fonts-anaconda -> font-ttf-dejavu-sans-mono
# font-ttf-dejavu-sans-mono
#
# Package libnetcdf conflicts for:
# libgdal -> libnetcdf[version='4.8.*|>=4.8.1,<5.0a0|>=4.6.1,<4.7.0a0|>=4.4.1.1,<4.4.2.0a0|>=4.8.1,<4.8.2.0a0']
# libnetcdf
# rasterio -> libgdal[version='>=3.0.2,<3.1.0a0'] -> libnetcdf[version='>=4.4.1.1,<4.4.2.0a0|>=4.6.1,<4.7.0a0|>=4.8.1,<5.0a0|>=4.8.1,<4.8.2.0a0']
#
# Package matplotlib-inline conflicts for:
# matplotlib-inline
# ipython -> matplotlib-inline[version='>=0.1.2']
# jupyterlab -> ipython -> matplotlib-inline[version='>=0.1.2']
# ipykernel -> matplotlib-inline[version='>=0.1.0,<0.2.0']
# ipykernel -> ipython[version='>=7.23.1'] -> matplotlib-inline[version='>=0.1.2']
# notebook -> ipykernel -> matplotlib-inline[version='>=0.1.0,<0.2.0']
#
# Package coverage conflicts for:
# attrs -> hypothesis -> coverage
# geopandas -> pysal -> coverage
#
# Package tbb4py conflicts for:
# numpy-base -> tbb4py
# mkl_fft -> numpy-base[version='>=1.0.6,<2.0a0'] -> tbb4py
# mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> tbb4py
# numpy -> numpy-base==1.15.4=py27h2753ae9_0 -> tbb4py
#
# Package snuggs conflicts for:
# rasterio -> snuggs[version='>=1.4.1']
# snuggs
#
# Package affine conflicts for:
# affine
# rasterio -> affine[version='>=1.3.0']
#
# Package winpty conflicts for:
# winpty
# terminado -> pywinpty[version='>=1.1.0'] -> winpty[version='>=0.4.3,<1.0a0']
# pywinpty -> winpty[version='>=0.4.3,<1.0a0']
#
# Package librttopo conflicts for:
# libspatialite -> librttopo[version='>=1.1.0,<1.2.0a0']
# librttopo
# libgdal -> libspatialite[version='>=5.0.1,<5.1.0a0'] -> librttopo[version='>=1.1.0,<1.2.0a0']
#
# Package contextvars conflicts for:
# sniffio -> contextvars[version='>=2.1']
# anyio -> sniffio[version='>=1.1'] -> contextvars[version='>=2.1']
#
# Package bottleneck conflicts for:
# geopandas -> pandas[version='>=0.23'] -> bottleneck[version='>=1.2.1|>=1.3.1']
# pandas -> bottleneck[version='>=1.2.1|>=1.3.1']
# bottleneck

# %%
import pandas as pd
import numpy as np
import leafmap
import geopandas as gpd
import branca.colormap as cm
from shapely.geometry import Point, Polygon, shape
from IPython.core.display import display, HTML, clear_output
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16328/3424000023.py in <module>
#       2 import numpy as np
#       3 import leafmap
# ----> 4 import geopandas as gpd
#       5 import branca.colormap as cm
#       6 from shapely.geometry import Point, Polygon, shape
#
# ModuleNotFoundError: No module named 'geopandas'
