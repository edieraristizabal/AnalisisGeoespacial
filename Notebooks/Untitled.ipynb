# %% [markdown]
# # Python en Sensores Remotos

# %% [markdown]
# ## Importar

# %%
import numpy as np
import matplotlib.pyplot as plt
from osgeo import gdal

# %%
mapa=np.genfromtxt(r'G:\My Drive\INVESTIGACION\PAPERS\ELABORACION\SHIA_George\resultados/PR_AMEACA.txt')

# %%
mapa_2=np.where(mapa==-9999.00,np.nan,mapa)
plt.imshow(mapa_2)
plt.colorbar();

# %%
landsat=gdal.Open("https://landsat-pds.s3.amazonaws.com/c1/L8/009/056/LC08_L1TP_009056_20210228_20210228_01_RT/LC08_L1TP_009056_20210228_20210228_01_RT_B3.TIF")

# %%
print(landsat.RasterCount)
# Out:
# 1

# %%
print(landsat)
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x000001D66E46C7B0> >

# %%
b3=landsat.GetRasterBand(1)

# %%
type(b3)
# Out:
# osgeo.gdal.Band

# %%
b3_matriz=b3.ReadAsArray()

# %%
type(b3_matriz)
# Out:
# numpy.ndarray

# %%
b3_matriz.shape
# Out:
# (7751, 7591)

# %%
b3_2=np.where(b3_matriz==0,np.nan,b3_matriz)
plt.imshow(b3_2)
plt.colorbar()
